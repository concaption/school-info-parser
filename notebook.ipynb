# %%
from src.csv_converter import json_to_csv

json_file = "data/output_files/WESTBOURNE ACADEMY STUDENT PRICES 2025_output.json"

json_to_csv(json_file)
# Out:
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:398 | Converting JSON to CSV, output path: None
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:402 | Input is a string, attempting to parse as JSON
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:350 | Starting JSON to DataFrame conversion
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:359 | School name found in nested structure: Westbourne Academy
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:165 | Starting to flatten school data for: Westbourne Academy
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:339 | Flattening complete. Processed 1 locations, 7 courses, 13 prices, created 13 rows.
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:375 | Successfully created DataFrame with 13 rows and 18 columns
# 2025-03-03 17:22:25 | INFO     | csv_converter.py:439 | No output path provided, returning DataFrame
#            school name         city country  \
# 0   Westbourne Academy  Bournemouth      GB
# 1   Westbourne Academy  Bournemouth      GB
# 2   Westbourne Academy  Bournemouth      GB
# 3   Westbourne Academy  Bournemouth      GB
# 4   Westbourne Academy  Bournemouth      GB
# 5   Westbourne Academy  Bournemouth      GB
# 6   Westbourne Academy  Bournemouth      GB
# 7   Westbourne Academy  Bournemouth      GB
# 8   Westbourne Academy  Bournemouth      GB
# 9   Westbourne Academy  Bournemouth      GB
# 10  Westbourne Academy  Bournemouth      GB
# 11  Westbourne Academy  Bournemouth      GB
# 12  Westbourne Academy  Bournemouth      GB
#
#                                     address  \
# 0   31 Alumhurst Road, Bournemouth, BH4 8EN
# 1   31 Alumhurst Road, Bournemouth, BH4 8EN
# 2   31 Alumhurst Road, Bournemouth, BH4 8EN
# 3   31 Alumhurst Road, Bournemouth, BH4 8EN
# 4   31 Alumhurst Road, Bournemouth, BH4 8EN
# 5   31 Alumhurst Road, Bournemouth, BH4 8EN
# 6   31 Alumhurst Road, Bournemouth, BH4 8EN
# 7   31 Alumhurst Road, Bournemouth, BH4 8EN
# 8   31 Alumhurst Road, Bournemouth, BH4 8EN
# 9   31 Alumhurst Road, Bournemouth, BH4 8EN
# 10  31 Alumhurst Road, Bournemouth, BH4 8EN
# 11  31 Alumhurst Road, Bournemouth, BH4 8EN
# 12  31 Alumhurst Road, Bournemouth, BH4 8EN
#
#                                     course name course type age range  \
# 0           General Main English Course (A1-C2)       Adult       16+
# 1           General Main English Course (A1-C2)       Adult       16+
# 2           General Main English Course (A1-C2)       Adult       16+
# 3           General Main English Course (A1-C2)       Adult       16+
# 4                   English Plus Course (A2-C2)       Adult       16+
# 5                   English Plus Course (A2-C2)       Adult       16+
# 6                   English Plus Course (A2-C2)       Adult       16+
# 7                   English Plus Course (A2-C2)       Adult       16+
# 8   Examination Courses - Cambridge (B2 and C1)       Adult       16+
# 9                Extra Intensive Course (A2-C1)       Adult       16+
# 10                           Junior Programme A   Teenagers     12-17
# 11                         General Main English       Adult       16+
# 12                                 English Plus       Adult       16+
#
#     lessons per week                                        description  \
# 0                 20                                               None
# 1                 20                                               None
# 2                 20                                               None
# 3                 20                                               None
# 4                 28                                               None
# 5                 28                                               None
# 6                 28                                               None
# 7                 28                                               None
# 8                 28                                               None
# 9                 40                                               None
# 10                20                           Children focused program
# 11                20  General English course focusing on improving f...
# 12                30  An advanced course for improving English speak...
#
#                                          requirements     duration  price  \
# 0                                                None    2-7 weeks  215.0
# 1                                                None   8-11 weeks  201.0
# 2                                                None  12-23 weeks  187.0
# 3                                                None    24+ weeks  170.0
# 4                                                None    2-7 weeks  262.0
# 5                                                None   8-11 weeks  245.0
# 6                                                None  12-23 weeks  227.0
# 7                                                None    24+ weeks  199.0
# 8   Students should enroll based on their examinat...  10-16 weeks  227.0
# 9                                                None    1-4 weeks  329.0
# 10                                               None    1-3 weeks  228.0
# 11                                               None       1 week  200.0
# 12                                               None       1 week  300.0
#
#     price value currency  total fee  \
# 0         215.0      GBP      215.0
# 1         201.0      GBP      215.0
# 2         187.0      GBP      215.0
# 3         170.0      GBP      215.0
# 4         262.0      GBP      262.0
# 5         245.0      GBP      262.0
# 6         227.0      GBP      262.0
# 7         199.0      GBP      262.0
# 8         227.0      GBP      227.0
# 9         329.0      GBP      329.0
# 10        228.0      GBP      228.0
# 11        200.0      GBP      200.0
# 12        300.0      GBP      300.0
#
#                                        accommodations  \
# 0   Type: Homestay, Price/week: 230 GBP, Descripti...
# 1   Type: Homestay, Price/week: 230 GBP, Descripti...
# 2   Type: Homestay, Price/week: 230 GBP, Descripti...
# 3   Type: Homestay, Price/week: 230 GBP, Descripti...
# 4   Type: Homestay, Price/week: 230 GBP, Descripti...
# 5   Type: Homestay, Price/week: 230 GBP, Descripti...
# 6   Type: Homestay, Price/week: 230 GBP, Descripti...
# 7   Type: Homestay, Price/week: 230 GBP, Descripti...
# 8   Type: Homestay, Price/week: 230 GBP, Descripti...
# 9   Type: Homestay, Price/week: 230 GBP, Descripti...
# 10  Type: Homestay, Price/week: 230 GBP, Descripti...
# 11  Type: Homestay, Price/week: 230 GBP, Descripti...
# 12  Type: Homestay, Price/week: 230 GBP, Descripti...
#
#                                       additional fees  \
# 0   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 1   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 2   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 3   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 4   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 5   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 6   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 7   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 8   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 9   enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 10  enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 11  enrollment_fee: 100.0 GBP; Homestay_week_Extra...
# 12  enrollment_fee: 100.0 GBP; Homestay_week_Extra...
#
#                                                 terms
# 0   cancellation_notes: Prices subject to revision...
# 1   cancellation_notes: Prices subject to revision...
# 2   cancellation_notes: Prices subject to revision...
# 3   cancellation_notes: Prices subject to revision...
# 4   cancellation_notes: Prices subject to revision...
# 5   cancellation_notes: Prices subject to revision...
# 6   cancellation_notes: Prices subject to revision...
# 7   cancellation_notes: Prices subject to revision...
# 8   cancellation_notes: Prices subject to revision...
# 9   cancellation_notes: Prices subject to revision...
# 10  cancellation_notes: Prices subject to revision...
# 11  cancellation_notes: Prices subject to revision...
# 12  cancellation_notes: Prices subject to revision...

# %%
#!/usr/bin/env python

import os
import base64
import json
import fitz  # PyMuPDF
from openai import OpenAI
from dotenv import load_dotenv
import io
from PIL import Image
from pydantic import BaseModel, Field
from typing import List, Dict, Optional
import logging
from logging.handlers import RotatingFileHandler
import sys
import traceback


# Set up logging
def setup_logging():
    # Create logs directory if it doesn't exist
    os.makedirs("logs", exist_ok=True)

    # Configure logging
    logger = logging.getLogger("PDFParser")
    logger.setLevel(logging.DEBUG)

    # File handler with rotation
    file_handler = RotatingFileHandler(
        "logs/pdf_parser.log", maxBytes=1024 * 1024, backupCount=5  # 1MB
    )
    file_handler.setLevel(logging.DEBUG)

    # Console handler
    console_handler = logging.StreamHandler(sys.stdout)
    console_handler.setLevel(logging.INFO)

    # Create formatters and add it to the handlers
    file_formatter = logging.Formatter(
        "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
    )
    console_formatter = logging.Formatter("%(levelname)s: %(message)s")

    file_handler.setFormatter(file_formatter)
    console_handler.setFormatter(console_formatter)

    # Add the handlers to the logger
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    return logger


# Initialize logger
logger = setup_logging()

# Load environment variables
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    logger.error("OpenAI API key not found in environment variables")
    raise ValueError("OpenAI API key not found")
class Price(BaseModel):
    duration: str = Field(..., description="Duration of the course")
    price: str = Field(..., description="Price of the course")
    currency: str = Field(..., description="Currency of the price")

class Course(BaseModel):
    name: str = Field(..., description="Name of the course")
    lessons_per_week: int = Field(..., description="Number of lessons per week")
    description: str = Field(..., description="Course description")
    prices: List[Price] = Field(..., description="List of prices for the course")
    requirements: Optional[str] = Field(None, description="Course requirements")

class Accommodation(BaseModel):
    type: str = Field(..., description="Type of accommodation")
    price_per_week: str = Field(..., description="Weekly price of accommodation")
    description: str = Field(..., description="Accommodation description")
    supplements: Optional[Dict[str, str]] = Field(default_factory=dict, description="Additional supplements")

class Location(BaseModel):
    city: str = Field(..., description="City where the school is located")
    country: str = Field(..., description="Country where the school is located")
    address: str = Field(..., description="Address of the school")
    courses: List[Course] = Field(..., description="List of available courses")
    accommodations: List[Accommodation] = Field(..., description="List of accommodations")
    additional_fees: Optional[Dict[str, str]] = Field(default_factory=dict, description="Additional fees")

class School(BaseModel):
    name: str = Field(..., description="Name of the school")
    locations: List[Location] = Field(..., description="List of locations where the school operates")
    terms: Optional[Dict[str, str]] = Field(default_factory=dict, description="Terms and conditions")

class PDFParser:
    def __init__(self, api_key):
        logger.info("Initializing PDFParser")

        self.client = OpenAI(api_key=api_key)
        self.system_prompt = """Please analyze this image and extract the language school information. Focus on identifying:
- School name
- Location details
- Course information
- Pricing
- Accommodation options
- Any terms or conditions

Format the response as valid JSON with this structure:
{
    "school_name": "Centre of English Studies",
    "locations": [
        {
            "city": "Dublin",
            "country": "Ireland",
            "address": "...",
            "courses": [
                {
                    "name": "Standard General English",
                    "lessons_per_week": 20,
                    "description": "Morning classes Mon-Fri",
                    "prices": [
                        {"duration": "2-4 weeks", "price": "€355", "currency": "EUR"}
                    ]
                }
            ],
            "accommodations": [
                {
                    "type": "Homestay",
                    "price_per_week": "€280",
                    "description": "Single room, half board",
                    "supplements": {
                        "Summer": "€35/week"
                    }
                }
            ],
            "additional_fees": {
                "registration": "€85"
            }
        }
    ],
    "terms": {
        "cancellation": "14 days notice required"
    }
}"""

    def parse_page(self, pixmap):
        try:
            logger.debug("Converting PyMuPDF pixmap to PIL Image")
            img = Image.frombytes("RGB", [pixmap.width, pixmap.height], pixmap.samples)

            logger.debug("Converting PIL Image to JPEG bytes")
            img_byte_arr = io.BytesIO()
            img.save(img_byte_arr, format="JPEG")
            img_byte_arr = img_byte_arr.getvalue()

            logger.debug("Encoding image to base64")
            base64_image = base64.b64encode(img_byte_arr).decode("utf-8")

            logger.info("Sending request to OpenAI API")
            response = self.client.beta.chat.completions.parse(
                model="gpt-4o-2024-11-20",
                messages=[
                    {
                        "role": "user",
                        "content": [
                            {"type": "text", "text": self.system_prompt},
                            {
                                "type": "image_url",
                                "image_url": {
                                    "url": f"data:image/jpeg;base64,{base64_image}"
                                },
                            },
                        ],
                    }
                ],
                max_completion_tokens=16383,
                response_format=School,
            )

            logger.debug("Received response from OpenAI API")

            # Log the raw response content for debugging
            logger.debug(
                f"Raw API response content: {response.choices[0].message.content}"
            )

            try:
                parsed_response = json.loads(response.choices[0].message.content)
                logger.info("Successfully parsed JSON response")
                return parsed_response
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse JSON response: {e}")
                logger.error(f"Response content: {response.choices[0].message.content}")
                raise

        except Exception as e:
            logger.error(f"Error in parse_page: {str(e)}")
            raise



class PDFProcessor:
    def __init__(self, api_key):
        logger.info("Initializing PDFProcessor")
        self.parser = PDFParser(api_key)
        self.results = []
    
    def process_pdf(self, pdf_path):
        logger.info(f"Processing PDF: {pdf_path}")
        try:
            if not os.path.exists(pdf_path):
                logger.error(f"PDF file not found: {pdf_path}")
                raise FileNotFoundError(f"PDF file not found: {pdf_path}")
            
            pdf_document = fitz.open(pdf_path)
            logger.info(f"Opened PDF with {pdf_document.page_count} pages")
            
            for page_num in range(pdf_document.page_count):
                logger.info(f"Processing page {page_num + 1}/{pdf_document.page_count}")
                page = pdf_document[page_num]
                pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
                
                try:
                    page_data = self.parser.parse_page(pix)
                    self.results.append(page_data)
                    logger.info(f"Successfully processed page {page_num + 1}")
                except Exception as e:
                    logger.error(f"Error processing page {page_num + 1}: {str(e)}")
            
            pdf_document.close()
            logger.info("PDF processing completed")
            # return self.merge_results()
            return self.results
            
        except Exception as e:
            logger.error(f"Error in process_pdf: {str(e)}")
            raise
    
    
    def safe_get_list(self, data: dict, key: str) -> list:
        """Safely get a list from a dictionary, handling None input."""
        if data is None:
            return []
        value = data.get(key, [])
        return value if isinstance(value, list) else []
        
    def safe_get_dict(self, data: dict, key: str) -> dict:
        """Safely get a dictionary from a dictionary, returning empty dict if None or not a dict."""
        if not isinstance(data, dict):
            logger.warning(f"Input is not a dictionary: {type(data)}")
            return {}
        value = data.get(key, {})
        if value is None:
            logger.warning(f"Found None value for key '{key}'")
            return {}
        if not isinstance(value, dict):
            logger.warning(f"Value for key '{key}' is not a dict: {type(value)}")
            return {}
        return value

    def merge_locations(self, locations: List[dict]) -> List[dict]:
        """
        Merge locations that refer to the same city, combining their courses and other details.
        """
        if not locations:
            logger.warning("No locations found to merge")
            return []
          # First pass: Filter out invalid entries
        valid_locations = []
        for loc in locations:
            if not isinstance(loc, dict):
                logger.warning(f"Skipping invalid location entry: {loc}")
                continue
            if not loc.get('city') or not loc.get('country'):
                logger.warning(f"Skipping location missing city/country: {loc}")
                continue
            valid_locations.append(loc)

        # Group locations by city and country
        location_map = {}
        for location in valid_locations:
            city = location.get('city')
            country = location.get('country')
            key = (city.lower().strip(), country.lower().strip())
            location_map.setdefault(key, []).append(location)

        merged_locations = []
        for (city, country), city_locations in location_map.items():
            merged_location = {
                'city': city,
                'country': country,
                'address': None,
                'courses': [],
                'accommodations': [],
                'additional_fees': {}
            }
            
            # Get first non-null address if available
            # Get first non-null address if available
            addresses = [loc.get('address') for loc in city_locations if loc.get('address')]
            if addresses:
                merged_location['address'] = addresses[0]
            
            # Track seen course names to avoid duplicates
            seen_courses = {}
            for location in city_locations:
                for course in self.safe_get_list(location, 'courses'):
                    if not isinstance(course, dict):
                        logger.warning(f"Skipping invalid course entry: {course}")
                        continue
                    
                    name = course.get('name')
                    if not name:
                        logger.warning(f"Skipping course without name: {course}")
                        continue
                    
                    course_key = (name, course.get('lessons_per_week'))
                    
                    if course_key not in seen_courses:
                        # New course - ensure all required fields exist
                        seen_courses[course_key] = {
                            'name': name,
                            'lessons_per_week': course.get('lessons_per_week'),
                            'description': course.get('description', ''),
                            'prices': self.safe_get_list(course, 'prices'),
                            'requirements': course.get('requirements', '')
                        }
                    else:
                        # Existing course - merge prices if they exist
                        existing_course = seen_courses[course_key]
                        course_prices = self.safe_get_list(course, 'prices')
                        if course_prices:
                            if not existing_course['prices']:
                                existing_course['prices'] = course_prices
                            else:
                                # Merge prices based on duration
                                price_map = {p.get('duration'): p for p in existing_course['prices'] if p.get('duration')}
                                for price in course_prices:
                                    if price.get('duration') and price.get('duration') not in price_map:
                                        existing_course['prices'].append(price)
                        
                        # Take the most detailed description
                        if len(course.get('description', '')) > len(existing_course.get('description', '')):
                            existing_course['description'] = course.get('description', '')
            
            merged_location['courses'] = list(seen_courses.values())
            
            # Merge accommodations
            seen_accommodations = {}
            for location in city_locations:
                for accommodation in self.safe_get_list(location, 'accommodations'):
                    if not isinstance(accommodation, dict):
                        logger.warning(f"Skipping invalid accommodation entry: {accommodation}")
                        continue
                    
                    acc_type = accommodation.get('type')
                    if not acc_type:
                        logger.warning(f"Skipping accommodation without type: {accommodation}")
                        continue
                    
                    if acc_type not in seen_accommodations:
                        seen_accommodations[acc_type] = {
                            'type': acc_type,
                            'price_per_week': accommodation.get('price_per_week'),
                            'description': accommodation.get('description', ''),
                            'supplements': accommodation.get('supplements', {})
                        }
                    else:
                        # Merge supplements if they exist
                        existing_acc = seen_accommodations[acc_type]
                        supplements = accommodation.get('supplements', {})
                        if supplements:
                            if not existing_acc['supplements']:
                                existing_acc['supplements'] = supplements
                            else:
                                existing_acc['supplements'].update(supplements)
                        
                        # Take non-null values from the new accommodation if they exist
                        if accommodation.get('price_per_week') and not existing_acc.get('price_per_week'):
                            existing_acc['price_per_week'] = accommodation['price_per_week']
                        
                        if len(accommodation.get('description', '')) > len(existing_acc.get('description', '')):
                            existing_acc['description'] = accommodation['description']
            
            merged_location['accommodations'] = list(seen_accommodations.values())
            
            # Merge additional fees
            for location in city_locations:
                additional_fees = location.get('additional_fees', {})
                if isinstance(additional_fees, dict):
                    merged_location.get('additional_fees').update(additional_fees)
            
            merged_locations.append(merged_location)
        
                   
            # Track seen course names to avoid duplicates
            seen_courses = {}
            for location in city_locations:
                for course in location.get('courses', []):
                    if not isinstance(course, dict):
                        logger.warning(f"Skipping invalid course entry: {course}")
                        continue
                        
                    name = course.get('name')
                    if not name:
                        logger.warning(f"Skipping course without name: {course}")
                        continue
                        
                    course_key = (name, course.get('lessons_per_week'))
                    
                    if course_key not in seen_courses:
                        # New course - ensure all required fields exist
                        seen_courses[course_key] = {
                            'name': name,
                            'lessons_per_week': course.get('lessons_per_week'),
                            'description': course.get('description', ''),
                            'prices': course.get('prices', []),
                            'requirements': course.get('requirements', '')
                        }
                    else:
                        # Existing course - merge prices if they exist
                        existing_course = seen_courses[course_key]
                        if course.get('prices'):
                            if not existing_course.get('prices'):
                                existing_course['prices'] = course['prices']
                            else:
                                # Merge prices based on duration
                                price_map = {p.get('duration'): p for p in existing_course['prices'] if p.get('duration')}
                                for price in course['prices']:
                                    if price.get('duration') and price.get('duration') not in price_map:
                                        existing_course['prices'].append(price)
                        
                        # Take the most detailed description
                        if len(course.get('description', '')) > len(existing_course.get('description', '')):
                            existing_course['description'] = course.get('description', '')
            
            merged_location['courses'] = list(seen_courses.values())
            
            # Merge accommodations
            seen_accommodations = {}
            for location in city_locations:
                accommodation_list = location.get('accommodations', [])
                if not isinstance(accommodation_list, list):
                    logger.warning(f"Invalid accommodations list: {accommodation_list}")
                    continue
                for accommodation in location.get('accommodations', []):
                    if not isinstance(accommodation, dict):
                        logger.warning(f"Skipping invalid accommodation entry: {accommodation}")
                        continue
                        
                    acc_type = accommodation.get('type')
                    if not acc_type:
                        logger.warning(f"Skipping accommodation without type: {accommodation}")
                        continue
                        
                    if acc_type not in seen_accommodations:
                        seen_accommodations[acc_type] = {
                            'type': acc_type,
                            'price_per_week': accommodation.get('price_per_week'),
                            'description': accommodation.get('description', ''),
                            'supplements': accommodation.get('supplements', {})
                        }
                    else:
                        # Merge supplements if they exist
                        existing_acc = seen_accommodations[acc_type]
                        if accommodation.get('supplements'):
                            if not existing_acc.get('supplements'):
                                existing_acc['supplements'] = accommodation['supplements']
                            else:
                                existing_acc['supplements'].update(accommodation['supplements'])
                                
                        # Take non-null values from the new accommodation if they exist
                        if accommodation.get('price_per_week') and not existing_acc.get('price_per_week'):
                            existing_acc['price_per_week'] = accommodation['price_per_week']
                            
                        if len(accommodation.get('description', '')) > len(existing_acc.get('description', '')):
                            existing_acc['description'] = accommodation['description']
            
            merged_location['accommodations'] = list(seen_accommodations.values())
            
            # Merge additional fees
            for location in city_locations:
                additional_fees = self.safe_get_dict(location, 'additional_fees')
                merged_location['additional_fees'].update(additional_fees)
            
            merged_locations.append(merged_location)
        
        logger.info(f"Merged {len(merged_locations)} locations")
        return merged_locations

    def merge_results(self):
        logger.info("Merging results from all pages")
        try:
            merged = {
                "school_name": "",
                "locations": [],
                "terms": {}
            }
            
            # Get first non-empty school name
            for page in self.results:
                if page and page.get("school_name"):
                    merged["school_name"] = page["school_name"]
                    break
            
            # Collect all locations
            all_locations = []
            for page in self.results:
                if page and isinstance(page, dict):
                    locations = page.get("locations", [])
                    if locations is None:
                        logger.warning(f"Found None for locations in page: {page}")
                        continue
                    if not isinstance(locations, list):
                        logger.warning(f"Locations is not a list: {type(locations)}")
                        continue
                    all_locations.extend(locations)
                else:
                    logger.warning(f"Invalid page data: {page}")
            
            logger.info(f"Collected {len(all_locations)} locations for merging")
            
            # Merge locations
            if not all_locations:
                logger.warning("No locations found to merge")
                return merged
                
            merged["locations"] = self.merge_locations(all_locations)
            
            # Merge terms
            for page in self.results:
                if page and isinstance(page, dict):
                    terms = page.get("terms", {})
                    if isinstance(terms, dict):
                        merged["terms"].update(terms)
            
            logger.info("Successfully merged results")
            return merged
            
        except Exception as e:
            logger.error(f"Error in merge_results: {str(e)}")
            raise

# %%
from utils import merge_all_results
import json

resutls_file = "data/output_files/2025_CES_Adult_Price_List_as_at_8th_August_output.json"
with open(resutls_file, "r") as f:
    results = json.load(f)

merged_results = merge_all_results(results.get("parsed_results", []))
with open("data/output_files/2025_CES_Adult_Price_List_as_at_8th_August_merged.json", "w") as f:
    json.dump(merged_results, f, indent=4)
# Out:
# 2025-02-04 16:13:06,675 - merger - INFO - Starting merge of 30 results
# 2025-02-04 16:13:06,677 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,679 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,680 - merger - INFO - Merging 1 locations with 1 locations
# 2025-02-04 16:13:06,680 - merger - INFO - Merging 1 courses with 2 courses
# 2025-02-04 16:13:06,682 - merger - INFO - Merging 1 accommodations with 1 accommodations
# 2025-02-04 16:13:06,683 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,684 - merger - INFO - Merging 1 locations with 1 locations
# 2025-02-04 16:13:06,684 - merger - INFO - Merging 3 courses with 2 courses
# 2025-02-04 16:13:06,685 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,686 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,687 - merger - INFO - Merging 1 locations with 1 locations
# 2025-02-04 16:13:06,688 - merger - INFO - Merging 5 courses with 2 courses
# 2025-02-04 16:13:06,689 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,690 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,691 - merger - INFO - Merging 1 locations with 1 locations
# 2025-02-04 16:13:06,692 - merger - INFO - Merging 7 courses with 3 courses
# 2025-02-04 16:13:06,692 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,693 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,694 - merger - INFO - Merging 1 locations with 2 locations
# 2025-02-04 16:13:06,695 - merger - INFO - Merging 10 courses with 2 courses
# 2025-02-04 16:13:06,696 - merger - INFO - Merging 2 accommodations with 3 accommodations
# 2025-02-04 16:13:06,696 - merger - INFO - Merging 11 courses with 1 courses
# 2025-02-04 16:13:06,698 - merger - INFO - Merging 5 accommodations with 0 accommodations
# 2025-02-04 16:13:06,698 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,699 - merger - INFO - Merging 1 locations with 1 locations
# 2025-02-04 16:13:06,700 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,701 - merger - INFO - Merging 2 locations with 1 locations
# 2025-02-04 16:13:06,702 - merger - INFO - Merging 2 courses with 3 courses
# 2025-02-04 16:13:06,703 - merger - INFO - Merging 0 accommodations with 0 accommodations
# 2025-02-04 16:13:06,704 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,705 - merger - INFO - Merging 2 locations with 1 locations
# 2025-02-04 16:13:06,706 - merger - INFO - Merging 5 courses with 8 courses
# 2025-02-04 16:13:06,707 - merger - INFO - Merging 0 accommodations with 0 accommodations
# 2025-02-04 16:13:06,707 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,708 - merger - INFO - Merging 2 locations with 1 locations
# 2025-02-04 16:13:06,710 - merger - INFO - Merging 13 courses with 0 courses
# 2025-02-04 16:13:06,710 - merger - INFO - Merging 0 accommodations with 2 accommodations
# 2025-02-04 16:13:06,712 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,713 - merger - INFO - Merging 2 locations with 1 locations
# 2025-02-04 16:13:06,715 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,717 - merger - INFO - Merging 3 locations with 2 locations
# 2025-02-04 16:13:06,718 - merger - INFO - Merging 3 courses with 8 courses
# 2025-02-04 16:13:06,718 - merger - INFO - Merging 0 accommodations with 0 accommodations
# 2025-02-04 16:13:06,719 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,721 - merger - INFO - Merging 4 locations with 1 locations
# 2025-02-04 16:13:06,722 - merger - INFO - Merging 11 courses with 1 courses
# 2025-02-04 16:13:06,723 - merger - INFO - Merging 0 accommodations with 2 accommodations
# 2025-02-04 16:13:06,724 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,726 - merger - INFO - Merging 4 locations with 1 locations
# 2025-02-04 16:13:06,727 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,728 - merger - INFO - Merging 5 locations with 1 locations
# 2025-02-04 16:13:06,730 - merger - INFO - Merging 5 courses with 3 courses
# 2025-02-04 16:13:06,730 - merger - INFO - Merging 0 accommodations with 3 accommodations
# 2025-02-04 16:13:06,731 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,733 - merger - INFO - Merging 5 locations with 2 locations
# 2025-02-04 16:13:06,734 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,736 - merger - INFO - Merging 7 locations with 2 locations
# 2025-02-04 16:13:06,737 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,739 - merger - INFO - Merging 9 locations with 1 locations
# 2025-02-04 16:13:06,740 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,742 - merger - INFO - Merging 10 locations with 1 locations
# 2025-02-04 16:13:06,743 - merger - INFO - Merging 3 courses with 0 courses
# 2025-02-04 16:13:06,744 - merger - INFO - Merging 2 accommodations with 2 accommodations
# 2025-02-04 16:13:06,745 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,752 - merger - INFO - Merging 10 locations with 1 locations
# 2025-02-04 16:13:06,755 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,757 - merger - INFO - Merging 11 locations with 1 locations
# 2025-02-04 16:13:06,760 - merger - INFO - Merging 3 courses with 0 courses
# 2025-02-04 16:13:06,761 - merger - INFO - Merging 0 accommodations with 3 accommodations
# 2025-02-04 16:13:06,762 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,767 - merger - INFO - Merging 11 locations with 1 locations
# 2025-02-04 16:13:06,769 - merger - INFO - Merging 3 courses with 0 courses
# 2025-02-04 16:13:06,770 - merger - INFO - Merging 3 accommodations with 3 accommodations
# 2025-02-04 16:13:06,771 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,775 - merger - INFO - Merging 11 locations with 1 locations
# 2025-02-04 16:13:06,778 - merger - INFO - Merging 3 courses with 0 courses
# 2025-02-04 16:13:06,779 - merger - INFO - Merging 3 accommodations with 3 accommodations
# 2025-02-04 16:13:06,780 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,783 - merger - INFO - Merging 11 locations with 1 locations
# 2025-02-04 16:13:06,788 - merger - INFO - Merging 3 courses with 2 courses
# 2025-02-04 16:13:06,789 - merger - INFO - Merging 3 accommodations with 3 accommodations
# 2025-02-04 16:13:06,790 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,793 - merger - INFO - Merging 11 locations with 1 locations
# 2025-02-04 16:13:06,795 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,798 - merger - INFO - Merging 12 locations with 1 locations
# 2025-02-04 16:13:06,801 - merger - INFO - Merging 9 courses with 1 courses
# 2025-02-04 16:13:06,802 - merger - INFO - Merging 0 accommodations with 2 accommodations
# 2025-02-04 16:13:06,803 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,806 - merger - INFO - Merging 12 locations with 3 locations
# 2025-02-04 16:13:06,808 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,810 - merger - INFO - Merging 5 accommodations with 0 accommodations
# 2025-02-04 16:13:06,811 - merger - INFO - Merging 0 courses with 0 courses
# 2025-02-04 16:13:06,812 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,814 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,816 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,817 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,820 - merger - INFO - Merging 12 locations with 3 locations
# 2025-02-04 16:13:06,823 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,825 - merger - INFO - Merging 5 accommodations with 0 accommodations
# 2025-02-04 16:13:06,826 - merger - INFO - Merging 0 courses with 0 courses
# 2025-02-04 16:13:06,827 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,829 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,832 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,834 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,836 - merger - INFO - Merging 12 locations with 3 locations
# 2025-02-04 16:13:06,839 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,840 - merger - INFO - Merging 5 accommodations with 0 accommodations
# 2025-02-04 16:13:06,841 - merger - INFO - Merging 0 courses with 0 courses
# 2025-02-04 16:13:06,842 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,844 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,845 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,846 - merger - INFO - Merging schools
# 2025-02-04 16:13:06,849 - merger - INFO - Merging 12 locations with 3 locations
# 2025-02-04 16:13:06,851 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,853 - merger - INFO - Merging 5 accommodations with 0 accommodations
# 2025-02-04 16:13:06,854 - merger - INFO - Merging 0 courses with 0 courses
# 2025-02-04 16:13:06,855 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,858 - merger - INFO - Merging 12 courses with 0 courses
# 2025-02-04 16:13:06,859 - merger - INFO - Merging 2 accommodations with 0 accommodations
# 2025-02-04 16:13:06,861 - merger - INFO - Merge completed successfully

# %%
merged_results
# Out:
# {'name': 'Centre of English Studies',
#  'locations': [{'city': 'Dublin',
#    'country': 'Ireland',
#    'address': '[Ces Dublin Address]',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'Morning classes Mon-Fri, 09:00-13:00',
#      'prices': [{'duration': '2-4 weeks', 'price': '€355', 'currency': 'EUR'},
#       {'duration': '5-8 weeks', 'price': '€340', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '€315', 'currency': 'EUR'},
#       {'duration': '12-23 weeks', 'price': '€285', 'currency': 'EUR'},
#       {'duration': '24-35 weeks', 'price': '€265', 'currency': 'EUR'},
#       {'duration': '36+ weeks', 'price': '€255', 'currency': 'EUR'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 26,
#      'description': 'Morning and afternoon classes',
#      'prices': [{'duration': '2-4 weeks', 'price': '€425', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '€400', 'currency': 'EUR'},
#       {'duration': '12-23 weeks', 'price': '€385', 'currency': 'EUR'},
#       {'duration': '24-35 weeks', 'price': '€345', 'currency': 'EUR'},
#       {'duration': '36+ weeks', 'price': '€330', 'currency': 'EUR'}],
#      'requirements': None},
#     {'name': 'Afternoon Lessons',
#      'lessons_per_week': 15,
#      'description': 'Afternoon classes from 13:45 to 17:00',
#      'prices': [{'duration': '2-4 weeks', 'price': '€200', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '€190', 'currency': 'EUR'},
#       {'duration': '12-23 weeks', 'price': '€180', 'currency': 'EUR'},
#       {'duration': '24-35 weeks', 'price': '€160', 'currency': 'EUR'},
#       {'duration': '36+ weeks', 'price': '€155', 'currency': 'EUR'}],
#      'requirements': 'Minimum booking of 4 weeks'},
#     {'name': 'Combination Course',
#      'lessons_per_week': 25,
#      'description': 'Group and one-to-one lessons',
#      'prices': [{'duration': '2-4 weeks', 'price': '€735', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '€700', 'currency': 'EUR'},
#       {'duration': '12+ weeks', 'price': '€675', 'currency': 'EUR'}],
#      'requirements': None},
#     {'name': 'IELTS Exam Preparation',
#      'lessons_per_week': 5,
#      'description': 'Test preparation services for IELTS Writing and Speaking.',
#      'prices': [{'duration': 'On-demand', 'price': '€225', 'currency': 'EUR'}],
#      'requirements': None}],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '€280',
#      'description': 'Single room, half board',
#      'supplements': {'Summer': '€35/week',
#       'Summer (30 June - 31 August)': '€35/week'}},
#     {'type': 'Homestay Accommodation',
#      'price_per_week': '€280',
#      'description': 'Single room accommodations with half-board meal plan, aimed for students aged 18+.',
#      'supplements': {'Summer Supplement': '€35/week (applied during June 1st to September 15th)',
#       'Special Diet Supplement': '€35/week (special dietary requirements)',
#       'Christmas Holidays Supplement': '€345 (one-time fee for December 20th to January 3rd period)'}},
#     {'type': 'Residential Accommodation (Auburn and Crestfield)',
#      'price_per_week': '€300 (single rooms) / €265 (shared rooms)',
#      'description': 'Self-catered facilities for students aged 18+.',
#      'supplements': None},
#     {'type': 'Residential Accommodation (Heyday)',
#      'price_per_week': '€399',
#      'description': 'Self-catered single rooms in modern residence with en-suite facilities.',
#      'supplements': None}],
#    'additional_fees': {'registration': '€85',
#     'Accommodation Placement Fee': '€85',
#     'Registration Fee for Courses': '€130',
#     'Medical Insurance Fee': 'Included (conditions for Europeans and other nationalities explained)',
#     'Textbook Fee': '€28 (standard) / €45 (IELTS-related)',
#     'Exams': 'IELTS €215, Advanced Cambridge Exam €210'}},
#   {'city': 'Leeds',
#    'country': 'United Kingdom',
#    'address': '[Ces Leeds Address]',
#    'courses': [{'name': 'IELTS Preparation',
#      'lessons_per_week': 25,
#      'description': 'Focused courses on IELTS preparation.',
#      'prices': [{'duration': '4 weeks', 'price': '£460', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'Focuses on general English language skills.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£255', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£250', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£240', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£230', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£225', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Intensive course with extra hours to improve quicker.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£375', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Combination Course',
#      'lessons_per_week': 25,
#      'description': 'Includes group lessons and one-to-one lessons.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£595', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£590', 'currency': 'GBP'},
#       {'duration': 'Extra week', 'price': '£580', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'IELTS Preparation Course',
#      'lessons_per_week': 30,
#      'description': 'General English and focused IELTS preparation.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£375', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£360', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£335', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£330', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Cambridge Exam Preparation Course (FCE)',
#      'lessons_per_week': 25,
#      'description': 'Focuses on preparation for the Cambridge English exam (FCE).',
#      'prices': [{'duration': '2-4 weeks', 'price': '£595', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£590', 'currency': 'GBP'},
#       {'duration': 'Extra week', 'price': '£580', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Long Term / Multi Destination Course',
#      'lessons_per_week': 20,
#      'description': 'English classes for long-term studies in multiple destinations.',
#      'prices': [{'duration': '24 weeks', 'price': '£5520', 'currency': 'GBP'},
#       {'duration': '36 weeks', 'price': '£8100', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'University Pathway Programme',
#      'lessons_per_week': 30,
#      'description': 'Preparation for university entry.',
#      'prices': [{'duration': '12 weeks', 'price': '£4260', 'currency': 'GBP'},
#       {'duration': '24 weeks', 'price': '£8040', 'currency': 'GBP'},
#       {'duration': 'Extra week', 'price': '£335', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Teacher Training Course',
#      'lessons_per_week': 20,
#      'description': 'Language development and teaching methodologies.',
#      'prices': [{'duration': '1 week', 'price': '£385', 'currency': 'GBP'},
#       {'duration': '2 weeks', 'price': '£765', 'currency': 'GBP'}],
#      'requirements': 'Professional teaching training background recommended.'},
#     {'name': 'CELTA Training Course',
#      'lessons_per_week': 20,
#      'description': 'Certification English teaching course.',
#      'prices': [{'duration': 'Face-to-Face',
#        'price': '£1545',
#        'currency': 'GBP'},
#       {'duration': 'Online (24-Week Part Time)',
#        'price': '£1515',
#        'currency': 'GBP'},
#       {'duration': 'Online (Part time or Full time)',
#        'price': '£1400',
#        'currency': 'GBP'}],
#      'requirements': 'Professional teaching requirements might apply.'},
#     {'name': 'General English with Business',
#      'lessons_per_week': 30,
#      'description': 'English applied to professional business contexts.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£375', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£360', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£360', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£335', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£330', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'One-to-One Lessons',
#      'lessons_per_week': 5,
#      'description': 'Individualized English lessons.',
#      'prices': [{'duration': 'Per hour', 'price': '£75', 'currency': 'GBP'}],
#      'requirements': None}],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '£215',
#      'description': 'Shared accommodation, half board',
#      'supplements': {'Summer': '£35/week',
#       'Christmas Holidays': '£350 for the duration',
#       'Special Diet': '£35/week'}},
#     {'type': 'Residence',
#      'price_per_week': '£225',
#      'description': 'Single en suite room, 18+ years, minimum 4 weeks',
#      'supplements': None}],
#    'additional_fees': {'registration': '£75',
#     'Accommodation Placement Fee': '£75'}},
#   {'city': 'Edinburgh',
#    'country': 'United Kingdom',
#    'address': '[Ces Edinburgh Address]',
#    'courses': [],
#    'accommodations': [],
#    'additional_fees': {}},
#   {'city': 'Cork',
#    'country': 'Ireland',
#    'address': '[Ces Cork Address]',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 18,
#      'description': 'General English course consisting of 18.33 contact hours per week.',
#      'prices': [{'duration': '2-4 weeks', 'price': '285', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '250', 'currency': 'EUR'},
#       {'duration': '12-23 weeks', 'price': '225', 'currency': 'EUR'},
#       {'duration': '24-35 weeks', 'price': '200', 'currency': 'EUR'},
#       {'duration': '36+ weeks', 'price': '190', 'currency': 'EUR'},
#       {'duration': 'n/a', 'price': 'n/a', 'currency': 'n/a'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 26,
#      'description': '09:00-13:00 Mon-Fri, 14:00-16:00 Tue-Thu',
#      'prices': [{'duration': '2-4 weeks', 'price': '350', 'currency': 'EUR'},
#       {'duration': '5-11 weeks', 'price': '315', 'currency': 'EUR'},
#       {'duration': '12-23 weeks', 'price': '290', 'currency': 'EUR'},
#       {'duration': '24-35 weeks', 'price': '265', 'currency': 'EUR'},
#       {'duration': '36+ weeks', 'price': '255', 'currency': 'EUR'}],
#      'requirements': None},
#     {'name': 'Afternoon Lessons',
#      'lessons_per_week': 15,
#      'description': '14:00-17:15 Mon-Fri',
#      'prices': [{'duration': '4 weeks minimum',
#        'price': '185 weekly',
#        'currency': 'EUR'}],
#      'requirements': 'Minimum 4 weeks'},
#     {'name': 'Combination Course',
#      'lessons_per_week': 30,
#      'description': '09:00-13:00 Mon-Fri group lessons plus 5 hours 1-on-1 lessons',
#      'prices': [{'duration': '12+ weeks',
#        'price': '615 weeks',
#        'currency': 'EUR'}],
#      'requirements': 'Minimum duration 12 weeks'}],
#    'accommodations': [{'type': 'Homestay Accommodation',
#      'price_per_week': '€270',
#      'description': 'Half board accommodation in carefully selected homestays',
#      'supplements': {'Extra Night': '€50'}},
#     {'type': 'Single Room Summer Supplement',
#      'price_per_week': '€50',
#      'description': 'Supplement for single room from May 17 to September 28',
#      'supplements': None},
#     {'type': 'Special Diet Supplement',
#      'price_per_week': '€35',
#      'description': 'For specialized dietary requirements (Coeliac, Gluten-free, Lactose-free, Vegan, Vegetarian)',
#      'supplements': None},
#     {'type': 'Christmas Holidays Homestay',
#      'price_per_week': '€345',
#      'description': 'Homestay accommodation fee during Christmas Holidays from 20 Dec to 3 Jan 2026',
#      'supplements': None},
#     {'type': 'Residential at University College Cork',
#      'price_per_week': '€285',
#      'description': 'Residential accommodation with additional cost for extra nights',
#      'supplements': {'Extra Night': '€50'}}],
#    'additional_fees': {'registration_fee': '85 EUR',
#     'Accommodation Placement Fee': '€85',
#     'Airport Transfer': '€60 (one way)',
#     'Medical Insurance for ILEP Students': '€130 per annum',
#     'Examination Fees': 'IELTS (€215), Cambridge First (€205), Advanced (€210)',
#     'Text Book Fees': 'Text Book + E-Book (€28), CES Coursebook (€45)'}},
#   {'city': 'Toronto',
#    'country': 'Canada',
#    'address': '[Ces Toronto Address]',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'Morning classes Mon-Fri',
#      'prices': [{'duration': '2-4 weeks', 'price': '$440', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$415', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$395', 'currency': 'USD'},
#       {'duration': '24-35 weeks', 'price': '$365', 'currency': 'USD'},
#       {'duration': '36+ weeks', 'price': '$345', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 25,
#      'description': 'Additional hours',
#      'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$420', 'currency': 'USD'},
#       {'duration': '24-35 weeks', 'price': '$400', 'currency': 'USD'},
#       {'duration': '36+ weeks', 'price': '$375', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Super Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Includes longer hours and intensive study schedule',
#      'prices': [{'duration': '2-4 weeks', 'price': '$500', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$475', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '24-35 weeks', 'price': '$420', 'currency': 'USD'},
#       {'duration': '36+ weeks', 'price': '$400', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'English for Digital Marketing',
#      'lessons_per_week': 20,
#      'description': 'Focuses on digital marketing skills',
#      'prices': [{'duration': '12 weeks', 'price': '$5340', 'currency': 'USD'}],
#      'requirements': 'B2 Entry required'},
#     {'name': 'University Pathway Program',
#      'lessons_per_week': 30,
#      'description': 'Preparation for university entry',
#      'prices': [{'duration': '12 weeks', 'price': '$5340', 'currency': 'USD'}],
#      'requirements': 'B2 Entry required'},
#     {'name': 'English for Business',
#      'lessons_per_week': 25,
#      'description': 'Combines general English and business English',
#      'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '12 weeks', 'price': '$420', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'General English for 30+',
#      'lessons_per_week': 20,
#      'description': 'General English specifically tailored for 30+ age group',
#      'prices': [{'duration': '2-4 weeks', 'price': '$440', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$415', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$395', 'currency': 'USD'},
#       {'duration': '24-35 weeks', 'price': '$365', 'currency': 'USD'},
#       {'duration': '36+ weeks', 'price': '$345', 'currency': 'USD'}],
#      'requirements': 'B1-B2 Entry required'},
#     {'name': 'Intensive IELTS Preparation Course',
#      'lessons_per_week': 25,
#      'description': 'Focus on IELTS preparation',
#      'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '12 weeks', 'price': '$420', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Super Intensive IELTS Preparation Course',
#      'lessons_per_week': 30,
#      'description': 'More intensive and thorough IELTS preparation',
#      'prices': [{'duration': '2-4 weeks', 'price': '$500', 'currency': 'USD'},
#       {'duration': '5-9 weeks', 'price': '$475', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Cambridge Examination Preparation Courses',
#      'lessons_per_week': 25,
#      'description': 'Prepare for Cambridge exams; includes one-on-one sessions',
#      'prices': [{'duration': '2-4 weeks', 'price': '$915', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$890', 'currency': 'USD'},
#       {'duration': '12 weeks', 'price': '$870', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Cambridge Examination Fast Track Courses',
#      'lessons_per_week': 30,
#      'description': 'Fast track Cambridge exam preparation within 4 weeks',
#      'prices': [{'duration': '4 weeks', 'price': '$2000', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'General English',
#      'lessons_per_week': 15,
#      'description': 'Focuses on all aspects of English language.',
#      'prices': [{'duration': '1-4 weeks',
#        'price': '$350/week',
#        'currency': 'CAD'}],
#      'requirements': None}],
#    'accommodations': [{'type': 'Homestay - Single Room',
#      'price_per_week': '$350',
#      'description': 'Full Board Single room.',
#      'supplements': {'Summer fee': '$30'}},
#     {'type': 'Residential Self Catering - Shared Room',
#      'price_per_week': '$525',
#      'description': 'Shared room accommodation.',
#      'supplements': {'Min stay': '4 weeks'}}],
#    'additional_fees': {'registration_fee': '$195',
#     'material_fee': '$20/week',
#     'private_lessons_general': '$85/lesson',
#     'private_lessons_exam_preparation': '$95/lesson',
#     'cambridge_materials_exam_administration': '$575',
#     'ielts_paper_based_exam': '$370',
#     'ielts_computer_based_exam': '$370',
#     'Accommodations Placement Fee': '$275',
#     'Airport Transfer': '$150'}},
#   {'city': 'Vancouver',
#    'country': 'Canada',
#    'address': '[Address Not Provided in Image]',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'Morning classes Mon-Fri, 09:00 - 12:15.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$440', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$415', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$395', 'currency': 'USD'},
#       {'duration': '24 weeks', 'price': '$365', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 25,
#      'description': 'Morning and early afternoon classes Mon-Thur, 09:00 - 14:00, and Friday 09:00 - 12:15.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$420', 'currency': 'USD'},
#       {'duration': '24 weeks', 'price': '$400', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Super Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Full day classes Mon-Thur, 09:00 - 15:15, and Friday 09:00 - 12:15.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$500', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$475', 'currency': 'USD'},
#       {'duration': '12-23 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '24 weeks', 'price': '$420', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Intensive IELTS Preparation Course',
#      'lessons_per_week': 25,
#      'description': 'IELTS preparation, 09:00 - 14:00 Mon-Thur and 09:00 - 12:15 Fri.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#       {'duration': '12 weeks', 'price': '$420', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Super Intensive IELTS Preparation Course',
#      'lessons_per_week': 30,
#      'description': 'IELTS preparation, 09:00 - 15:15 Mon-Thur and 09:00 - 12:15 Fri.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$500', 'currency': 'USD'},
#       {'duration': '5-9 weeks', 'price': '$475', 'currency': 'USD'}],
#      'requirements': None},
#     {'name': 'Cambridge Examination Preparation Course',
#      'lessons_per_week': 20,
#      'description': 'Focus on FCE & CAE examinations, with additional one-to-one lessons, 09:00 - 12:15 Mon-Fri.',
#      'prices': [{'duration': '2-4 weeks', 'price': '$915', 'currency': 'USD'},
#       {'duration': '5-11 weeks', 'price': '$890', 'currency': 'USD'},
#       {'duration': '12 weeks', 'price': '$870', 'currency': 'USD'}],
#      'requirements': 'Exam dates: FCE: June 10, CAE: June 4; FCE: Nov 25, CAE: Nov 26.'},
#     {'name': 'Cambridge Examination Fast Track Preparation Course',
#      'lessons_per_week': 30,
#      'description': 'Intensive FCE & CAE preparation, 09:00 - 15:15 Mon-Thurs, 09:00 - 12:15 Fri. Specific start and exam dates.',
#      'prices': [{'duration': '4 weeks', 'price': '$2000', 'currency': 'USD'}],
#      'requirements': 'Course start dates: Jul 2 / Jul 28. Exam dates: Jul 24 (FCE) / Jul 25 (CAE), Aug 22 (CAE).'}],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '$480',
#      'description': 'Executive half-board accommodation with private bathroom.',
#      'supplements': {'Summer surcharge': '$30/week from 1 June to 31 August.'}},
#     {'type': 'Residential',
#      'price_per_week': '$600',
#      'description': 'Casa Canada. Shared accommodation in downtown Vancouver.',
#      'supplements': {}}],
#    'additional_fees': {'registration': '$195',
#     'general_private_lesson': '$85 per lesson',
#     'exam_private_lesson': '$95 per lesson',
#     'Cambridge_material_exam': '$575',
#     'material_per_week': '$20 p/w',
#     'Accommodation placement fee': '$275',
#     'Airport transfer (one way)': '$150',
#     'Medical Insurance': '$3/day'}},
#   {'city': 'London',
#    'country': 'United Kingdom',
#    'address': '-',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'General English Course conducted Monday to Friday',
#      'prices': [{'duration': '2-4 weeks', 'price': '£275', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£265', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£255', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£250', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£240', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Intensive English Course Monday to Friday mornings and afternoons',
#      'prices': [{'duration': '2-4 weeks', 'price': '£390', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£370', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£365', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£345', 'currency': 'GBP'}],
#      'requirements': None}],
#    'accommodations': [],
#    'additional_fees': {'registration_fee': '£75'}},
#   {'city': 'London',
#    'country': 'England',
#    'address': 'Rathbone Apartments, Zone 1 Central London',
#    'courses': [],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '£280',
#      'description': 'Half-board accommodation',
#      'supplements': {'Summer': '£35 p/w (July and August)',
#       'Special Diet': '£35 p/w',
#       'Christmas': '£350 p/w'}},
#     {'type': 'Residential',
#      'price_per_week': 'Varies',
#      'description': 'Accommodation in apartments',
#      'supplements': {'Minimum Stay': '4 weeks', 'Resident Age': '18+'}}],
#    'additional_fees': {'registration': '£75'}},
#   {'city': 'Edinburgh',
#    'country': 'Scotland',
#    'address': 'Rathbone Apartments',
#    'courses': [],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '£280',
#      'description': 'Half-board accommodation',
#      'supplements': {'Summer': '£35 p/w (July and August)',
#       'Special Diet': '£35 p/w',
#       'Christmas': '£350 p/w'}}],
#    'additional_fees': None},
#   {'city': 'Oxford',
#    'country': 'United Kingdom',
#    'address': 'N/A',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 15,
#      'description': 'General English course.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£275', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£265', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£255', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£250', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£240', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Morning classes + Afternoon lessons Tues-Thu',
#      'prices': [{'duration': '2-4 weeks', 'price': '£390', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£370', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£365', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£345', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Combination Course',
#      'lessons_per_week': 25,
#      'description': 'Morning lessons Mon-Fri + Afternoon One-to-One lessons',
#      'prices': [{'duration': '2-4 weeks', 'price': '£615', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£605', 'currency': 'GBP'}],
#      'requirements': 'English proficiency required'},
#     {'name': 'IELTS Preparation Course',
#      'lessons_per_week': 30,
#      'description': 'Morning and afternoon classes focusing on IELTS exam preparation.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£390', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£370', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£365', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£355', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Cambridge Exam Preparation Course',
#      'lessons_per_week': 25,
#      'description': 'Combination of group lessons and One-to-One lessons focusing on Cambridge exams.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£615', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£605', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Long Term/Multi-Destination Course',
#      'lessons_per_week': 20,
#      'description': '24 to 36 weeks course across Ireland and UK.',
#      'prices': [{'duration': '24 weeks', 'price': '£6000', 'currency': 'GBP'},
#       {'duration': '36 weeks', 'price': '£8640', 'currency': 'GBP'}],
#      'requirements': 'Flight not included'},
#     {'name': 'IELTS Preparation',
#      'lessons_per_week': 15,
#      'description': 'Focused on preparing students for the IELTS exam.',
#      'prices': [{'duration': 'N/A', 'price': '£220', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Intensive English Course',
#      'lessons_per_week': 22,
#      'description': 'Includes extra lessons per week for more in-depth learning.',
#      'prices': [],
#      'requirements': None}],
#    'accommodations': [{'type': 'Homestay',
#      'price_per_week': '£210',
#      'description': 'Includes breakfast and dinner, shared rooms available',
#      'supplements': {'Summer': '£30 per week'}},
#     {'type': 'Student Residence',
#      'price_per_week': '£175',
#      'description': 'Private room, self-catering',
#      'supplements': {'Summer': '£20 per week'}},
#     {'type': 'Private Apartment',
#      'price_per_week': '£300',
#      'description': 'Fully furnished apartment',
#      'supplements': {'Cleaning': '£30 per week'}},
#     {'type': 'Host Family (Single Room, Half Board)',
#      'price_per_week': '£280',
#      'description': 'Single room accommodation, half board.',
#      'supplements': {'Summer': '£35/week (July and August)',
#       'Diet': '£35/week',
#       'Holiday Rate': '£350/week (20 Dec to 03 Jan 2026)'}},
#     {'type': 'Host Family (Shared Room, Half Board)',
#      'price_per_week': '£235',
#      'description': 'Shared room accommodation, half board.',
#      'supplements': {'Summer': '£35/week (July and August)'}}],
#    'additional_fees': {'registration_fee': '£75',
#     'extra_week_fee': '£595',
#     'Accommodation Placement Fee': '£75',
#     'Text Book (Digital)': '£32',
#     'In-Term Activities': 'Varies based on activity.'}},
#   {'city': 'Worthing',
#    'country': 'United Kingdom',
#    'address': 'Worthing, UK',
#    'courses': [{'name': 'Standard General English',
#      'lessons_per_week': 20,
#      'description': 'General English course with 20 lessons per week. 09:30 - 13:00 Mon to Fri.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£245', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£235', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£225', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£220', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£210', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Intensive General English',
#      'lessons_per_week': 30,
#      'description': 'Intensive General English course offering 30 lessons per week. 09:30 - 13:00 and 14:00 - 16:30 Tue to Thurs.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£335', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£325', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£315', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£305', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Combination Course',
#      'lessons_per_week': 25,
#      'description': 'Combination of group and one-to-one lessons perfect for personalized learning. Mon to Fri, morning group lessons followed by one-to-one in afternoons.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£585', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£575', 'currency': 'GBP'},
#       {'duration': 'extra week', 'price': '£565', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'IELTS Preparation Course',
#      'lessons_per_week': 30,
#      'description': '30 lessons per week including IELTS preparation in afternoons.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£335', 'currency': 'GBP'},
#       {'duration': '12-23 weeks', 'price': '£325', 'currency': 'GBP'},
#       {'duration': '24-35 weeks', 'price': '£315', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£305', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Cambridge Exam Preparation Course (FCE)',
#      'lessons_per_week': 25,
#      'description': '20 group lessons/week plus afternoons for FCE-focused preparation.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£585', 'currency': 'GBP'},
#       {'duration': '5-11 weeks', 'price': '£575', 'currency': 'GBP'},
#       {'duration': 'extra week', 'price': '£565', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Long Term / Multidestination Course Ireland and UK - 20 Lessons',
#      'lessons_per_week': 20,
#      'description': 'Long term program with 20 lessons per week in multiple locations.',
#      'prices': [{'duration': '24 weeks', 'price': '£5280', 'currency': 'GBP'},
#       {'duration': '36 weeks', 'price': '£7560', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Long Term / Multidestination Course Ireland and UK - 30 Lessons',
#      'lessons_per_week': 30,
#      'description': 'Long term program with 30 lessons per week in multiple locations.',
#      'prices': [{'duration': '24 weeks', 'price': '£7560', 'currency': 'GBP'},
#       {'duration': '36 weeks', 'price': '£10890', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'University Pathway Program',
#      'lessons_per_week': 30,
#      'description': '12 and 24 week courses preparing for university enrollment.',
#      'prices': [{'duration': '12 weeks', 'price': '£4260', 'currency': 'GBP'},
#       {'duration': '24 weeks', 'price': '£7560', 'currency': 'GBP'},
#       {'duration': 'extra week', 'price': '£315', 'currency': 'GBP'}],
#      'requirements': None},
#     {'name': 'Teacher Training Courses',
#      'lessons_per_week': 20,
#      'description': 'Offered as 1 and 2 week courses with language development and methodology.',
#      'prices': [{'duration': '1 Week', 'price': '£385', 'currency': 'GBP'},
#       {'duration': '2 Weeks', 'price': '£770', 'currency': 'GBP'}],
#      'requirements': 'Must attend pre-training.'},
#     {'name': 'CELTA Training Course',
#      'lessons_per_week': 20,
#      'description': 'Comprehensive CELTA certification online.',
#      'prices': [{'duration': '24 Week - Part Time',
#        'price': '£1515',
#        'currency': 'GBP'},
#       {'duration': 'Full Time', 'price': '£1400', 'currency': 'GBP'}],
#      'requirements': 'CELTA registration process applies.'},
#     {'name': 'General English with Business',
#      'lessons_per_week': 30,
#      'description': 'Focused on incorporating business English elements.',
#      'prices': [{'duration': '2-4 weeks', 'price': '£355', 'currency': 'GBP'},
#       {'duration': '36+ weeks', 'price': '£305', 'currency': 'GBP'}],
#      'requirements': 'Intermediate level English.'},
#     {'name': 'One to One Lessons',
#      'lessons_per_week': 5,
#      'description': 'Customized personal tutoring.',
#      'prices': [{'duration': '1 Hour', 'price': '£75', 'currency': 'GBP'}],
#      'requirements': 'Available on demand, scheduling applies.'},
#     {'name': 'Standard Course',
#      'lessons_per_week': 15,
#      'description': '15 contact hours per week, excluding breaks.',
#      'prices': [],
#      'requirements': None},
#     {'name': 'Intensive Course',
#      'lessons_per_week': 22,
#      'description': '22 contact hours per week, excluding breaks.',
#      'prices': [],
#      'requirements': None}],
#    'accommodations': [{'type': 'Host Family',
#      'price_per_week': '£350',
#      'description': 'Christmas Holidays Homestay accommodation fee, 20 Dec to 3 Jan each year',
#      'supplements': {'Summer': '£35/week'}}],
#    'additional_fees': {'type': 'Registration',
#     'amount': '£75',
#     'registration_fee': '£75',
#     'Accommodation Placement Fee': '£75',
#     'Special Diet Supplement': '£35 per week',
#     'Text book': '£32'}}],
#  'terms': {'cancellation': 'Cancel or modify bookings early when possible.',
#   'accommodation_refunds': 'Refunds are processed only when duly canceled beforehand.',
#   'exam_conditions': 'Students must acquire desired English proficiency for specialized tests.',
#   'holidays_and_off_days': 'Six mentioned no-class days for the year 2025.',
#   'strict_cancellation_policy': 'Secondary or specific fees are precise upon constraint handling (voluntary withdrawal dates etc.).',
#   'breakfast_timings_reg': 'Dublin College Staff reserves ideal lunch documentation protocols ensuring.',
#   'evening_guidelines_for_rec_periods_noted': 'Shops locally reassure similar fringe learners adapted journeys.',
#   'cancellation_policy': 'All cancellations must be notified in writing.',
#   'accommodation': 'Accommodation is arranged in approved locations according to British Council guidelines.',
#   'school_holidays': 'Holidays include Jan 01, Feb 03, Mar 17, April 18/21, May 02/Jun 04, Aug 04, Oct 27, Dec 19-Jan 05.',
#   'social_activities': 'Participation in social activities costs vary between €15 and €65 per activity.',
#   'Accommodation': 'Accommodation is arranged in a carefully selected homestay on request.',
#   'Classes': 'All teaching/tuition hours are 45 minutes.',
#   'Medical Insurance': 'You are strongly advised to take out travel and medical insurance before leaving home.',
#   'max_hours_per_week': '14 sessions of 45 minutes each',
#   'Insurance': 'Students are advised to have travel and medical insurance before departure.',
#   'Examinations': 'IELTS exam costs £220.',
#   'Social Activities': 'A range of social activities for varied fees.',
#   'Refund Policy': 'No refunds for missed term dates or holidays.',
#   'School Holidays': 'List of dates at which classes are not conducted.',
#   'Tuition Hours': 'Standard courses are 15 contact hours per week.',
#   'Holidays': '01 January, 18 April, 01 April, 05 May, 26 May, 25 August, 22 December 2025 - 02 January 2026',
#   'Cancellation Policy': 'No refund or time given in lieu for public holidays',
#   'Text Book': 'Digital E-book cost is £32.',
#   'Policy of Care': 'CES has a strict policy of care and welfare for all 16- and 17-year-old students in adult schools.',
#   'payment_information': 'Payment in full is required four weeks prior to the start date. Refund policies apply for cancellations and visa refusals.',
#   'more_details': 'Refer to image or CES official website for additional details.'},
#  'repeat': True}

# %%
logger.info("Starting PDF processing")
processor = PDFProcessor(api_key=OPENAI_API_KEY)
result = processor.process_pdf("data/input_files/2025_CES_Adult_Price_List_as_at_8th_August.pdf")

# %%
result
# Out:
# [{'name': 'Centre of English Studies',
#   'locations': [{'city': 'Dublin',
#     'country': 'Ireland',
#     'address': 'Not specified',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'General English for improving communication skills',
#       'prices': [{'duration': '2-4 weeks', 'price': '355', 'currency': 'EUR'},
#        {'duration': '5-11 weeks', 'price': '€315', 'currency': 'EUR'},
#        {'duration': '12-23 weeks', 'price': '€285', 'currency': 'EUR'},
#        {'duration': '24-35 weeks', 'price': '€265', 'currency': 'EUR'},
#        {'duration': '36+ weeks', 'price': '€255', 'currency': 'EUR'}],
#       'requirements': None}],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '280',
#       'description': 'Single room, half board',
#       'supplements': {'summer': '35/week',
#        'summer_supplement': '€35 per week',
#        'Single Room Summer Supplement': '€35/week from June 1st to September 1st',
#        'Special Diet Supplement': '€35/week',
#        'Christmas Supplement': '€345 for December 20, 2025 to January 3, 2026'}}],
#     'additional_fees': {'registration': '85'}}],
#   'terms': {'cancellation': '14 days notice required'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Dublin',
#     'country': 'Ireland',
#     'address': 'Not provided',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'Morning classes Mon-Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '€355', 'currency': 'EUR'},
#        {'duration': '5-11 weeks', 'price': '€315', 'currency': 'EUR'},
#        {'duration': '12-23 weeks', 'price': '€285', 'currency': 'EUR'},
#        {'duration': '24-35 weeks', 'price': '€265', 'currency': 'EUR'},
#        {'duration': '36+ weeks', 'price': '€255', 'currency': 'EUR'}],
#       'requirements': None},
#      {'name': 'Intensive General English',
#       'lessons_per_week': 26,
#       'description': 'Morning and afternoon classes Mon-Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '€425', 'currency': 'EUR'},
#        {'duration': '5-11 weeks', 'price': '€400', 'currency': 'EUR'},
#        {'duration': '12-23 weeks', 'price': '€385', 'currency': 'EUR'},
#        {'duration': '24-35 weeks', 'price': '€345', 'currency': 'EUR'},
#        {'duration': '36+ weeks', 'price': '€330', 'currency': 'EUR'}],
#       'requirements': None}],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '€280',
#       'description': 'Single room, half board',
#       'supplements': {'summer_supplement': '€35 per week'}}],
#     'additional_fees': {'registration_fee': '€85'}}],
#   'terms': {'registration_fees_appliy_to_all': '€85',
#    'lesson_duration': '55 minutes'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Dublin',
#     'country': 'Ireland',
#     'address': 'N/A',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '€280',
#       'description': 'Includes single room and meals (breakfast and dinner).',
#       'supplements': {'Single Room Summer Supplement': '€35/week from June 1st to September 1st',
#        'Special Diet Supplement': '€35/week',
#        'Christmas Supplement': '€345 for December 20, 2025 to January 3, 2026'}},
#      {'type': 'Residential - Auburn and Crestfield',
#       'price_per_week': 'From €300 (Single), €265 (Shared)',
#       'description': 'Self-catering, private residences, 5km to city.',
#       'supplements': None},
#      {'type': 'Residential - Heyday',
#       'price_per_week': '€399',
#       'description': 'Self-catering, individual room within walking distance.',
#       'supplements': None}],
#     'additional_fees': {'Airport Transfer': '€85 for one-way'}}],
#   'terms': {'accommodation': 'Includes homestay and residential options. Meals are conditional on accommodation.',
#    'insurance': 'Medi insurance and EU EHIC card recommended.',
#    'payment': 'Non-refundable with exceptions during specified periods.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Cork',
#     'country': 'Ireland',
#     'address': '.',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': '20 lessons per week, 09:00 - 13:00 Monday to Friday',
#       'prices': [{'duration': '2-4 weeks', 'price': '€285', 'currency': 'EUR'},
#        {'duration': '5-11 weeks', 'price': '€250', 'currency': 'EUR'},
#        {'duration': '12-23 weeks', 'price': '€225', 'currency': 'EUR'}],
#       'requirements': 'Available all year'}],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '€200',
#       'description': 'Single room with meal plans included',
#       'supplements': {'summer_fee': '€20 per week',
#        'Christmas Holidays': '€345/week from 20 Dec to 03 Jan',
#        'Single Room Summer': '€50/week from May 17 to September 28',
#        'Special Diet': '€35/week for various diets such as gluten-free or vegetarian'}}],
#     'additional_fees': {'registration_fee': '€85 for all students'}}],
#   'terms': {'conditions': 'All teaching hours are 55 minutes. Maximum class size is 14 students.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Cork',
#     'country': 'Ireland',
#     'address': 'Not specified',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '€270',
#       'description': 'Homestay accommodation with meals.',
#       'supplements': {'Christmas Holidays': '€345/week from 20 Dec to 03 Jan',
#        'Single Room Summer': '€50/week from May 17 to September 28',
#        'Special Diet': '€35/week for various diets such as gluten-free or vegetarian'}},
#      {'type': 'Residential',
#       'price_per_week': '€285',
#       'description': 'Accommodation at University College Cork.',
#       'supplements': None},
#      {'type': 'Airport pickup',
#       'price_per_week': '€60',
#       'description': 'One-way transfer to homestay or residence.',
#       'supplements': None}],
#     'additional_fees': {'Accommodation Placement Fee': '€85'}}],
#   'terms': {'tuition_hours': 'Standard Course is 18.33 hours per week and Intensive Course is 23.83 hours per week.',
#    'insurance': '€130 per annum for Medi-PEL',
#    'examinations': 'IELTS: €215, Cambridge First: €205, Advanced: €210',
#    'textbook': 'Textbook and e-book fee: €28, IELTS book: €45',
#    'policy_of_care': 'Care policy for 16 and 17-year-old students in adult courses.',
#    'school_holidays': 'No classes on January 01, February 03, March 17, April 18, April 21, May 02, June 04, August 27, October 19, December 25 to January 05, 2026.'}},
#  {'name': 'Centre of English Studies - Toronto',
#   'locations': [{'city': 'Toronto',
#     'country': 'Canada',
#     'address': 'Unknown',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'Morning classes Monday to Friday, 09:00 to 12:15.',
#       'prices': [{'duration': '2-4 weeks', 'price': '$440', 'currency': 'CAD'},
#        {'duration': '5-11 weeks', 'price': '$415', 'currency': 'CAD'},
#        {'duration': '12-23 weeks', 'price': '$395', 'currency': 'CAD'},
#        {'duration': '24-35 weeks', 'price': '$365', 'currency': 'CAD'},
#        {'duration': '36+ weeks', 'price': '$345', 'currency': 'CAD'}],
#       'requirements': None}],
#     'accommodations': [],
#     'additional_fees': {'registration_fee': '$195'}}],
#   'terms': {'teaching_minutes': '45 minutes',
#    'maximum_class_size': '16 trainees'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Toronto',
#     'country': 'Canada',
#     'address': 'Unavailable',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '350',
#       'description': 'Full-Board Accommodation (Single)',
#       'supplements': {'summer_additional_cost': '30 per week 01 June - 31 Aug'}},
#      {'type': 'Residence',
#       'price_per_week': '525',
#       'description': 'Casa Canada (18+ Shared Room, Weekly with Tax)',
#       'supplements': {'monthly_discount': 'Minimum 4 weeks'}}],
#     'additional_fees': {'accommodation_placement_fee': '275',
#      'medical_insurance': '3 per day'}}],
#   'terms': {'accommodation_notice': 'Students must arrive at their scheduled time, changes incur extra fees.',
#    'medical_insurance': 'Strongly recommended. Covers tuition fees and belongings loss due to cancellation.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Vancouver',
#     'country': 'Canada',
#     'address': '',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': '09:00 to 12:15 Mon-Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '$440', 'currency': 'USD'},
#        {'duration': '5-11 weeks', 'price': '$415', 'currency': 'USD'},
#        {'duration': '12-23 weeks', 'price': '$395', 'currency': 'USD'},
#        {'duration': '24 weeks', 'price': '$365', 'currency': 'USD'}],
#       'requirements': None},
#      {'name': 'Intensive General English',
#       'lessons_per_week': 25,
#       'description': '09:00 to 14:00 Mon-Thu, 09:00 to 12:15 Fridays',
#       'prices': [{'duration': '2-4 weeks', 'price': '$465', 'currency': 'USD'},
#        {'duration': '5-11 weeks', 'price': '$445', 'currency': 'USD'},
#        {'duration': '12-23 weeks', 'price': '$420', 'currency': 'USD'},
#        {'duration': '24 weeks', 'price': '$400', 'currency': 'USD'}],
#       'requirements': None}],
#     'accommodations': [],
#     'additional_fees': {'registration': '$195'}}],
#   'terms': None},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Vancouver',
#     'country': 'Canada',
#     'address': '',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '$375',
#       'description': 'Full board single room, additional cost during summer.',
#       'supplements': {'Special Diet': '$45 p/w', 'Extra Night': '$60'}},
#      {'type': 'Homestay',
#       'price_per_week': '$360',
#       'description': 'Half board single room, additional cost during summer.',
#       'supplements': {'Special Diet': '$45 p/w', 'Extra Night': '$60'}},
#      {'type': 'Homestay',
#       'price_per_week': '$480',
#       'description': 'Executive half-board with private bathroom.',
#       'supplements': {}},
#      {'type': 'Residence',
#       'price_per_week': '$600',
#       'description': 'Economy Downtown.',
#       'supplements': {'Monthly Rate': '$2400'}}],
#     'additional_fees': {'Accommodation Placement Fee': '$275'}}],
#   'terms': {'Accommodation Policy': 'Accommodation is arranged upon request.',
#    'Medical Insurance Policy': 'Ensure coverage before leaving home.',
#    'Tuition Hour Policy': 'Standard Course is 15 hours per week, excluding breaks.',
#    'Additional Notes': 'Late arrival fees apply.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'London',
#     'country': 'England',
#     'address': '',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'Morning classes Mon-Fri 9:30-13:00',
#       'prices': [{'duration': '2-4 weeks', 'price': '£275', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£265', 'currency': 'GBP'},
#        {'duration': '12+ weeks', 'price': '£255', 'currency': 'GBP'}],
#       'requirements': None},
#      {'name': 'Intensive General English',
#       'lessons_per_week': 30,
#       'description': 'Morning and afternoon classes, Mon-Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '£390', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£370', 'currency': 'GBP'},
#        {'duration': '12+ weeks', 'price': '£365', 'currency': 'GBP'}],
#       'requirements': None}],
#     'accommodations': [],
#     'additional_fees': {'registration': '£75'}}],
#   'terms': None},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'London',
#     'country': 'United Kingdom',
#     'address': '',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay (Single)',
#       'price_per_week': '£280',
#       'description': 'Homestay accommodation with half-board.',
#       'supplements': {'Summer Supplement': '£35 per week (July and August)'}},
#      {'type': 'Homestay (Shared)',
#       'price_per_week': '£235',
#       'description': 'Shared Homestay accommodation with half-board.',
#       'supplements': {'Summer Supplement': '£35 per week (July and August)'}},
#      {'type': 'Rathbone Apartments Residential',
#       'price_per_week': '£275 and up',
#       'description': 'Residential accommodation located in Zone 1 in London, available for adults 18+ with a minimum stay of 4 weeks.',
#       'supplements': None}],
#     'additional_fees': {'accommodation placement fee': '£75'}},
#    {'city': 'Edinburgh',
#     'country': 'United Kingdom',
#     'address': '',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay (Single)',
#       'price_per_week': '£280',
#       'description': 'Homestay accommodation with half-board.',
#       'supplements': {'Summer Supplement': '£35 per week (July and August)'}},
#      {'type': 'Homestay (Shared)',
#       'price_per_week': '£235',
#       'description': 'Shared Homestay accommodation with half-board.',
#       'supplements': {'Summer Supplement': '£35 per week (July and August)'}}],
#     'additional_fees': {'accommodation placement fee': '£75'}}],
#   'terms': {'accommodation': 'Rules and policies for accommodations are as described in the image.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Oxford',
#     'country': 'UK',
#     'address': 'N/A',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'Morning classes Mon-Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '£275', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£265', 'currency': 'GBP'}],
#       'requirements': None},
#      {'name': 'IELTS Preparation Course',
#       'lessons_per_week': 30,
#       'description': 'Morning classes Mon-Fri and afternoons with IELTS focus',
#       'prices': [{'duration': '2-4 weeks',
#         'price': '£390',
#         'currency': 'GBP'}],
#       'requirements': None}],
#     'accommodations': [],
#     'additional_fees': {'registration_fee': '£75'}}],
#   'terms': {'cancellation': '14 days notice required for cancellation'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Oxford',
#     'country': 'United Kingdom',
#     'address': 'Not specified',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '£280 (Single, Standard)',
#       'description': 'Includes half-board accommodation (breakfast and dinner).',
#       'supplements': {'Summer Supplement (July and August)': '£35 per week',
#        'Christmas Holidays Accommodation Fee': '£350 for the period of 20 Dec to 3 Jan 2026'}}],
#     'additional_fees': {'Airport Transfer from Heathrow Airport': '£165 (1 passenger), £170 (2 passengers), £175 (3 passengers)',
#      'Airport Transfer from Gatwick Airport': '£205 (1 passenger), £210 (2 passengers), £215 (3 passengers)',
#      'Airport Transfer from Stansted Airport': '£215 (1 passenger), £220 (2 passengers), £225 (3 passengers)'}}],
#   'terms': {'Accommodation Policy': 'Half-board, single room guaranteed only for specific periods.',
#    'Medical Insurance': 'Not included, needs to be arranged by the student.',
#    'Tuition Hours': '45 minutes per teaching hour for courses.',
#    'Examinations': 'IELTS exam cost is £220.',
#    'Social Activities': 'Optional activities available with costs ranging from £8 to £120, depending on type.',
#    'School Holidays': 'Specified dates; no refund for these holidays.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Leeds',
#     'country': 'United Kingdom',
#     'address': '6th January - 19th December 2025',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': '09:30-13:00 Mon to Fri',
#       'prices': [{'duration': '2-4 weeks', 'price': '£255', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£250', 'currency': 'GBP'},
#        {'duration': '12-23 weeks', 'price': '£240', 'currency': 'GBP'},
#        {'duration': '24-35 weeks', 'price': '£230', 'currency': 'GBP'},
#        {'duration': '36+ weeks', 'price': '£225', 'currency': 'GBP'}],
#       'requirements': None},
#      {'name': 'Intensive General English',
#       'lessons_per_week': 30,
#       'description': '09:30-13:00 Mon to Fri & 14:00-16:30 Tues to Thurs',
#       'prices': [{'duration': '2-4 weeks', 'price': '£375', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£360', 'currency': 'GBP'},
#        {'duration': '12-23 weeks', 'price': '£355', 'currency': 'GBP'},
#        {'duration': '24-35 weeks', 'price': '£335', 'currency': 'GBP'},
#        {'duration': '36+ weeks', 'price': '£330', 'currency': 'GBP'}],
#       'requirements': None}],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': 'N/A',
#       'description': 'Details not provided',
#       'supplements': None}],
#     'additional_fees': {'registration_fee': '£75'}}],
#   'terms': None},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Leeds',
#     'country': 'United Kingdom',
#     'address': '-',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': '£240',
#       'description': 'Half-board, single room',
#       'supplements': {'summer': '£35/pw', 'Christmas': '£350'}},
#      {'type': 'Residence',
#       'price_per_week': '£225',
#       'description': 'Year-round, single en-suite room',
#       'supplements': None}],
#     'additional_fees': {'accommodation_placement': '£75',
#      'IELTS_exam': '£220',
#      'digital_ebook': '£32'}}],
#   'terms': {'accommodation': 'Accommodation is arranged by request.',
#    'medical_insurance': 'Strongly advised to take out.',
#    'other_terms': 'Special activities available.'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Worthing',
#     'country': 'United Kingdom',
#     'address': '',
#     'courses': [{'name': 'Standard General English',
#       'lessons_per_week': 20,
#       'description': 'Morning classes Mon-Fri, 9:30 - 13:00',
#       'prices': [{'duration': '2-4 weeks', 'price': '£245', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£235', 'currency': 'GBP'},
#        {'duration': '12-23 weeks', 'price': '£225', 'currency': 'GBP'},
#        {'duration': '24-35 weeks', 'price': '£220', 'currency': 'GBP'},
#        {'duration': '36+ weeks', 'price': '£210', 'currency': 'GBP'}],
#       'requirements': None},
#      {'name': 'Intensive General English',
#       'lessons_per_week': 30,
#       'description': 'Morning and afternoon classes Mon-Fri, 9:30 - 13:00 & 14:00 - 16:30',
#       'prices': [{'duration': '2-4 weeks', 'price': '£355', 'currency': 'GBP'},
#        {'duration': '5-11 weeks', 'price': '£335', 'currency': 'GBP'}],
#       'requirements': None}],
#     'accommodations': [],
#     'additional_fees': None}],
#   'terms': {'cancellation': '14 days notice required'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Worthing',
#     'country': 'United Kingdom',
#     'address': '',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay (Half-Board)',
#       'price_per_week': 'Single room: £240 p/w, Shared room: £215 p/w',
#       'description': 'Half board with options for summer and special diet supplements.',
#       'supplements': {'summer_supplement': '£35 p/w during July and August',
#        'special_diet_supplement': '£35 p/w',
#        'Christmas_homestay_accommodation': '£350 p/w (20 Dec to 3 Jan 2026)'}}],
#     'additional_fees': {'accommodation_placement_fee': '£75',
#      'airport_transfers_one_way_from_Heathrow': '£170 (one passenger), £175 (two passengers), £180 (three passengers)',
#      'airport_transfers_one_way_from_Gatwick': '£140 (one passenger), £145 (two passengers), £150 (three passengers)',
#      'airport_transfers_one_way_from_Stansted': '£250 (one passenger), £255 (two passengers), £260 (three passengers)'}},
#    {'city': '',
#     'country': '',
#     'address': '',
#     'courses': [],
#     'accommodations': [],
#     'additional_fees': None}],
#   'terms': {'accommodation_terms': 'Accommodation in carefully selected homestay, half board.',
#    'tuition_hours': 'Standard course: 15 contact hrs/week. Intensive course: 22 contact hrs/week.',
#    'tuition_hours_notes': 'All lessons are 45 minutes each.',
#    'exam_fee': 'IELTS exam costs: €220 (subject to change).',
#    'additional_materials': 'Digital E-Book: €32.',
#    'social_activities': 'Organized excursions at an additional cost.',
#    'holidays': '01 January, 18–21 April, 5 May, 26 May, 25 August, 22 December (2025), 02 January (2026).'}},
#  {'name': 'Centre of English Studies',
#   'locations': [{'city': 'Dublin',
#     'country': 'Ireland',
#     'address': '72 Dame Street, Dublin 2, Ireland',
#     'courses': [],
#     'accommodations': [{'type': 'Homestay',
#       'price_per_week': 'Varies',
#       'description': 'Fully furnished accommodation with meals.',
#       'supplements': None},
#      {'type': 'Self-catering',
#       'price_per_week': 'Varies',
#       'description': 'Self-service accommodations.',
#       'supplements': None}],
#     'additional_fees': {'registration': 'Varies'}},
#    {'city': 'Toronto',
#     'country': 'Canada',
#     'address': '5807 Street West, Toronto, Ontario, MAW 1A3',
#     'courses': [],
#     'accommodations': [],
#     'additional_fees': {}},
#    {'city': 'West Sussex',
#     'country': 'United Kingdom',
#     'address': '27 South Street, Worthing West Sussex, BN11 3AR',
#     'courses': [],
#     'accommodations': [],
#     'additional_fees': {}}],
#   'terms': {'cancellation': 'Cancellation fees apply for cancellations made 14 days prior to course start.'}}]

# %%
import copy


def merge_accommodation_details(existing: dict, new: dict):
    """Merge details of two accommodation dictionaries"""
    # Update scalar fields
    for field in ['price_per_week', 'description']:
        if new.get(field):
            existing[field] = new[field]
    
    # Handle None values for supplements
    existing_supp = existing.get('supplements') or {}
    new_supp = new.get('supplements') or {}
    existing_supp.update(new_supp)
    existing['supplements'] = existing_supp

def merge_location_details(existing: dict, new: dict):
    """Merge details of two location dictionaries"""
    # Update address if missing
    if not existing.get('address') and new.get('address'):
        existing['address'] = new['address']
    
    # Merge courses
    existing['courses'] = merge_courses(existing.get('courses', []), new.get('courses', []))
    
    # Merge accommodations
    existing['accommodations'] = merge_accommodations(
        existing.get('accommodations', []),
        new.get('accommodations', [])
    )
    
    # Merge additional fees (handle None values)
    existing_fees = existing.get('additional_fees') or {}
    new_fees = new.get('additional_fees') or {}
    existing_fees.update(new_fees)
    existing['additional_fees'] = existing_fees

def merge_schools(school1: dict, school2: dict) -> dict:
    """Merge two school dictionaries into one"""
    if not school1:
        return copy.deepcopy(school2)
    
    merged = copy.deepcopy(school1)
    
    # Merge terms (handle None values)
    merged_terms = merged.get('terms') or {}
    merged_terms.update(school2.get('terms') or {})
    merged['terms'] = merged_terms

    # Merge locations
    merged['locations'] = merge_locations(merged.get('locations', []), school2.get('locations', []))
    
    return merged


def merge_locations(locations1: list, locations2: list) -> list:
    """Merge two lists of locations"""
    merged = copy.deepcopy(locations1)
    
    for loc2 in locations2:
        existing = find_location(merged, loc2['city'], loc2['country'])
        if not existing:
            merged.append(copy.deepcopy(loc2))
            continue
        
        # Merge location details
        merge_location_details(existing, loc2)
    
    return merged

def find_location(locations: list, city: str, country: str) -> Optional[dict]:
    """Find a location in a list by city and country"""
    return next(
        (l for l in locations if l['city'] == city and l['country'] == country),
        None
    )


def merge_courses(courses1: list, courses2: list) -> list:
    """Merge two lists of courses"""
    merged = copy.deepcopy(courses1)
    
    for course2 in courses2:
        existing = find_course(merged, course2['name'])
        if not existing:
            merged.append(copy.deepcopy(course2))
            continue
        
        # Update course details
        merge_course_details(existing, course2)
    
    return merged

def find_course(courses: list, name: str) -> Optional[dict]:
    """Find a course in a list by name"""
    return next((c for c in courses if c['name'] == name), None)

def merge_course_details(existing: dict, new: dict):
    """Merge details of two course dictionaries"""
    # Update scalar fields
    for field in ['lessons_per_week', 'description', 'requirements']:
        if new.get(field):
            existing[field] = new[field]
    
    # Merge prices
    existing['prices'] = merge_prices(existing.get('prices', []), new.get('prices', []))

def merge_prices(prices1: list, prices2: list) -> list:
    """Merge two lists of prices"""
    merged = {p['duration']: copy.deepcopy(p) for p in prices1}
    for price in prices2:
        merged[price['duration']] = copy.deepcopy(price)
    return list(merged.values())

def merge_accommodations(acc1: list, acc2: list) -> list:
    """Merge two lists of accommodations"""
    merged = copy.deepcopy(acc1)
    
    for acc in acc2:
        existing = find_accommodation(merged, acc['type'])
        if not existing:
            merged.append(copy.deepcopy(acc))
            continue
        
        # Update accommodation details
        merge_accommodation_details(existing, acc)
    
    return merged

def find_accommodation(accommodations: list, acc_type: str) -> Optional[dict]:
    """Find an accommodation in a list by type"""
    return next((a for a in accommodations if a['type'] == acc_type), None)

def merge_all_results(results: list) -> dict:
    """Merge all results from multiple pages into a single school dictionary"""
    if not results:
        return {}
    
    merged = {}
    for result in results:
        merged = merge_schools(merged, result)
    
    return merged

# %%
merged_data = merge_all_results(result)

# %%
# conver merged result to json
merged_result_json = json.dumps(merged_data, indent=4)
# save the result to a file
with open("data/output_files/merged_resulsast.json", "w") as f:
    f.write(merged_result_json)

# %%
import json
import pandas as pd
from typing import List, Dict, Any
import logging

def setup_logging():
    """Set up basic logging configuration"""
    logging.basicConfig(level=logging.INFO)
    return logging.getLogger(__name__)

logger = setup_logging()

def format_supplements(supplements: Dict[str, Any]) -> str:
    """Format supplements dictionary into a readable string"""
    if not supplements:
        return ""
    return "; ".join(f"{k}: {v}" for k, v in supplements.items())

def format_additional_fees(fees: Dict[str, Any]) -> str:
    """Format additional fees dictionary into a readable string"""
    if not fees:
        return ""
    return "; ".join(f"{k}: {v}" for k, v in fees.items())

def format_terms(terms: Dict[str, Any]) -> str:
    """Format terms dictionary into a readable string"""
    if not terms:
        return ""
    return "; ".join(f"{k}: {v}" for k, v in terms.items())

def format_accommodations(accommodations: List[Dict[str, Any]]) -> str:
    """Format accommodations list into a readable string"""
    if not accommodations:
        return ""
    acc_details = []
    for acc in accommodations:
        details = f"Type: {acc.get('type', 'N/A')}"
        if acc.get('price_per_week'):
            details += f", Price/week: {acc['price_per_week']}"
        if acc.get('description'):
            details += f", Description: {acc['description']}"
        if acc.get('supplements'):
            details += f", Supplements: {format_supplements(acc['supplements'])}"
        acc_details.append(details)
    return " | ".join(acc_details)

def flatten_school_data(json_data: Dict) -> List[Dict]:
    """
    Flattens JSON school data into a list of dictionaries, each representing a row in the final CSV.
    Handles merged results structure with accommodations, terms, and additional fees.
    """
    all_rows = []
    
    for file_result in json_data.get('results', []):
        file_name = next(iter(file_result))
        result_data = file_result[file_name]
        
        if not result_data.get('merged_results'):
            logger.warning(f"No merged results found for {file_name}")
            continue
            
        merged_data = result_data['merged_results']
        school_name = merged_data.get('name', '')
        school_terms = merged_data.get('terms', {})
        
        for location in merged_data.get('locations', []):
            city = location.get('city', '')
            country = location.get('country', '')
            address = location.get('address', '')
            accommodations = location.get('accommodations', [])
            additional_fees = location.get('additional_fees', {})
            
            # Format the complex fields
            formatted_accommodations = format_accommodations(accommodations)
            formatted_fees = format_additional_fees(additional_fees)
            formatted_terms = format_terms(school_terms)
            
            for course in location.get('courses', []):
                course_name = course.get('name', '')
                lessons_per_week = course.get('lessons_per_week', '')
                description = course.get('description', '')
                requirements = course.get('requirements', '')
                
                prices = course.get('prices', [])
                if prices:
                    for price in prices:
                        row = {
                            'File Name': file_name,
                            'School Name': school_name,
                            'City': city,
                            'Country': country,
                            'Address': address,
                            'Course Name': course_name,
                            'Lessons Per Week': lessons_per_week,
                            'Description': description,
                            'Requirements': requirements,
                            'Duration': price.get('duration', ''),
                            'Price': price.get('price', ''),
                            'Currency': price.get('currency', ''),
                            'Accommodations': formatted_accommodations,
                            'Additional Fees': formatted_fees,
                            'Terms': formatted_terms
                        }
                        all_rows.append(row)
                else:
                    row = {
                        'File Name': file_name,
                        'School Name': school_name,
                        'City': city,
                        'Country': country,
                        'Address': address,
                        'Course Name': course_name,
                        'Lessons Per Week': lessons_per_week,
                        'Description': description,
                        'Requirements': requirements,
                        'Duration': '',
                        'Price': '',
                        'Currency': '',
                        'Accommodations': formatted_accommodations,
                        'Additional Fees': formatted_fees,
                        'Terms': formatted_terms
                    }
                    all_rows.append(row)
    
    return all_rows

def convert_json_to_csv(json_file_path: str, output_csv_path: str):
    """
    Converts JSON file to CSV format.
    
    Args:
        json_file_path (str): Path to input JSON file
        output_csv_path (str): Path for output CSV file
    """
    try:
        # Read JSON file
        with open(json_file_path, 'r', encoding='utf-8') as file:
            json_data = json.load(file)
        
        # Flatten the data
        flattened_data = flatten_school_data(json_data)
        
        if not flattened_data:
            logger.error("No data was extracted from the JSON file")
            return
        
        # Convert to DataFrame
        df = pd.DataFrame(flattened_data)
        
        # Clean column names
        df.columns = df.columns.str.replace('[^a-zA-Z0-9]', '_')
        
        # Write to CSV
        df.to_csv(output_csv_path, index=False, encoding='utf-8')
        logger.info(f"CSV file created successfully: {output_csv_path}")
        logger.info(f"Total rows written: {len(df)}")
        
    except Exception as e:
        logger.error(f"Error processing file: {str(e)}")
        raise

if __name__ == "__main__":
    # Example usage
    file_name="f609b04c-d84f-4df1-925d-5192a1c7ea54"
    json_file_path = f"data/output_files/{file_name}.json"  # Replace with your JSON file path
    output_csv_path = f"data/output_files/{file_name}.csv"  # Replace with desired output path
    convert_json_to_csv(json_file_path, output_csv_path)
# Out:
# INFO:__main__:CSV file created successfully: data/output_files/f609b04c-d84f-4df1-925d-5192a1c7ea54.csv
# INFO:__main__:Total rows written: 959
